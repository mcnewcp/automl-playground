# %% [markdown]
# # Purpose
#
# The purpose of this notebook is to explore the usage of [auto-sklearn](https://automl.github.io/auto-sklearn/master/) for automated algorithm selection and hyperparameter tuning.
#
# ## Data
#
# The CA housing data will be used for this example, which is a simple regressiont task. It will be loaded from the sklearn data loader. I'll split off 20% into a test set which `auto-sklearn` won't see during selection and tuning.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
import pandas as pd

housing = fetch_california_housing()

X_train, X_test, y_train, y_test = train_test_split(
    housing.data, housing.target, test_size=0.2
)

pd.DataFrame(X_train, columns=housing.feature_names).describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  16512.000000  16512.000000  16512.000000  16512.000000  16512.000000
# mean       3.863213     28.607013      5.435929      1.098311   1421.535187
# std        1.892192     12.586631      2.617797      0.508852   1085.579217
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.559875     18.000000      4.440973      1.005882    785.000000
# 50%        3.531750     29.000000      5.227585      1.048611   1165.500000
# 75%        4.741375     37.000000      6.048902      1.099367   1725.250000
# max       15.000100     52.000000    141.909091     34.066667  16122.000000
#
#            AveOccup      Latitude     Longitude
# count  16512.000000  16512.000000  16512.000000
# mean       3.103588     35.632925   -119.566449
# std       11.598327      2.135489      2.005619
# min        0.750000     32.540000   -124.260000
# 25%        2.428532     33.940000   -121.800000
# 50%        2.817672     34.260000   -118.500000
# 75%        3.281481     37.720000   -118.000000
# max     1243.333333     41.950000   -114.470000

# %% [markdown]
# # Select and Fit Regressor
#
# Now I'll let `auto-sklearn` select a regressor and tune hyperparameters.  I'll give it 10 minutes for the task and I'll use mean squared error for the metric.

# %%
import autosklearn.regression

automl = autosklearn.regression.AutoSklearnRegressor(
    time_left_for_this_task = 600,
    tmp_folder = "/tmp/autosklearn_regression_example_tmp"
)
automl.fit(X_train, y_train, dataset_name="CA Housing")
# Out:
# AutoSklearnRegressor(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                      per_run_time_limit=60, time_left_for_this_task=600,
#                      tmp_folder='/tmp/autosklearn_regression_example_tmp')

# %% [markdown]
# # View the Model Leaderboard

# %%
automl.leaderboard()
# Out:
#           rank  ensemble_weight               type      cost   duration
# model_id
# 5            1             0.10  gradient_boosting  0.170541   8.954080
# 7            2             0.02  gradient_boosting  0.170775   3.923948
# 15           3             0.28  gradient_boosting  0.171231   4.121505
# 36           4             0.18  gradient_boosting  0.172118   6.252859
# 6            5             0.22  gradient_boosting  0.173452   8.697344
# 47           6             0.02  gradient_boosting  0.176753  15.958781
# 19           7             0.06  gradient_boosting  0.178071   2.157974
# 46           8             0.08  gradient_boosting  0.178671   2.899472
# 30           9             0.04  gradient_boosting  0.178881  15.132808

# %% [markdown]
# # View Final Ensemble

# %%
automl.show_models()
# Out:
# {5: {'model_id': 5, 'rank': 1, 'cost': 0.1705412164216238, 'ensemble_weight': 0.1, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff435c37640>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff435c37580>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff435c37310>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=1.3053128884667706e-10,
#                               learning_rate=0.05594167483605857, max_iter=512,
#                               max_leaf_nodes=85, min_samples_leaf=10,
#                               n_iter_no_change=4, random_state=1,
#                               validation_fraction=None, warm_start=True)}, 6: {'model_id': 6, 'rank': 2, 'cost': 0.17345160413346683, 'ensemble_weight': 0.22, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff435b3a4f0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff435cf3b80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff435cf32b0>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=6.085630700044881e-10,
#                               learning_rate=0.12392806728650493, max_iter=512,
#                               min_samples_leaf=25, n_iter_no_change=7,
#                               random_state=1, validation_fraction=None,
#                               warm_start=True)}, 7: {'model_id': 7, 'rank': 3, 'cost': 0.17077535057481863, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff435b3a280>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff43581f5b0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff43581f640>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=2.208787572338781e-05,
#                               learning_rate=0.036087332404571744, max_iter=512,
#                               max_leaf_nodes=64, min_samples_leaf=3,
#                               n_iter_no_change=18, random_state=1,
#                               validation_fraction=None, warm_start=True)}, 15: {'model_id': 15, 'rank': 4, 'cost': 0.17123123463034462, 'ensemble_weight': 0.28, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff4357bbca0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff432839940>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff432839a30>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=6.536723381440492e-05,
#                               learning_rate=0.03940103065495631, max_iter=512,
#                               max_leaf_nodes=77, min_samples_leaf=9,
#                               n_iter_no_change=7, random_state=1,
#                               validation_fraction=None, warm_start=True)}, 19: {'model_id': 19, 'rank': 5, 'cost': 0.17807129496846452, 'ensemble_weight': 0.06, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff43588fdc0>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff42d870220>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff42d870340>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=0.013442521728157596,
#                               learning_rate=0.15308825058123207, max_iter=256,
#                               max_leaf_nodes=26, min_samples_leaf=6,
#                               n_iter_no_change=20, random_state=1,
#                               validation_fraction=0.08504769517258337,
#                               warm_start=True)}, 30: {'model_id': 30, 'rank': 6, 'cost': 0.1788807771665717, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff432834130>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff42afe0e80>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff42afe0f40>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=1.104595032093826e-10,
#                               learning_rate=0.053052481330717806, max_iter=512,
#                               max_leaf_nodes=161, min_samples_leaf=10,
#                               n_iter_no_change=4, random_state=1,
#                               validation_fraction=None, warm_start=True)}, 36: {'model_id': 36, 'rank': 7, 'cost': 0.1721175515450437, 'ensemble_weight': 0.18, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff42d8dda30>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff426492e20>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff426492f40>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=9.78250029322458e-06,
#                               learning_rate=0.05568948682604825, max_iter=512,
#                               max_leaf_nodes=72, min_samples_leaf=6,
#                               n_iter_no_change=18, random_state=1,
#                               warm_start=True)}, 46: {'model_id': 46, 'rank': 8, 'cost': 0.17867060248488664, 'ensemble_weight': 0.08, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff42d7c8190>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff4263009a0>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff426300ac0>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=1.3892847247386306e-09,
#                               learning_rate=0.16017734352643365, max_iter=512,
#                               max_leaf_nodes=7, min_samples_leaf=124,
#                               n_iter_no_change=1, random_state=1,
#                               validation_fraction=None, warm_start=True)}, 47: {'model_id': 47, 'rank': 9, 'cost': 0.1767529627536628, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7ff426488610>, 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7ff4260bf250>, 'regressor': <autosklearn.pipeline.components.regression.RegressorChoice object at 0x7ff4260bf310>, 'sklearn_regressor': HistGradientBoostingRegressor(l2_regularization=6.57665987661635e-08,
#                               learning_rate=0.05574497276612266, max_iter=512,
#                               max_leaf_nodes=69, min_samples_leaf=6,
#                               random_state=1, validation_fraction=None,
#                               warm_start=True)}}

# %% [markdown]
# # Score the Final Model

# %%
from sklearn.metrics import mean_squared_error

train_predictions = automl.predict(X_train)
print("Train MSE:", mean_squared_error(y_train, train_predictions))
test_predictions = automl.predict(X_test)
print("Test MSE:", mean_squared_error(y_test, test_predictions))
# Out:
# Train MSE: 0.09253990016835716
# Test MSE: 0.17995909199317583

# %% [markdown]
# # View Residuals

# %%
import matplotlib.pyplot as plt
import numpy as np

plot_min = np.min(np.concatenate([test_predictions, train_predictions, y_train, y_test]))
plot_max = np.max(np.concatenate([test_predictions, train_predictions, y_train, y_test]))

plt.scatter(train_predictions, y_train, label="Train samples", c="#d95f02")
plt.scatter(test_predictions, y_test, label="Test samples", c="#7570b3")
plt.xlabel("Predicted value")
plt.ylabel("True value")
plt.legend()
plt.plot([plot_min, plot_max], [plot_min, plot_max], c="k", zorder=0)
plt.xlim([plot_min, plot_max])
plt.ylim([plot_min, plot_max])
plt.tight_layout()
plt.show()
